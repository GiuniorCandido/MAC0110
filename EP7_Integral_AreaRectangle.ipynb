# %% [markdown]
# Integral pelo método dos retângulos
#
# Exercitar mais ainda a criação e uso de funções: funções como parâmetros, retorno de vários valores e argumento opcional.
# Manipular valores float que são representações aproximadas em ponto flutuante de número reais.
# Obter valores aproximados de uma função.
# Introduzir teoria do erro através dos conceito de erro absoluto e erro relativo.
# Uso da biblioteca math.
# Introduzir o uso de módulos em Python.
#
# Nesse exercício você deve implementar as seguintes duas funções:
#
#     #------------------------------------------------
#     def integral_por_retangulos(f, a, b, k):
#         ''' (função, float, float, int) -> float
#
#         Calcula uma aproximação da integral da função f
#         no intervalo [a,b] usando k retângulos.
#         '''
#         # corpo da função
#         [...]
#         return aproximacao # nome ilustrativo
#
#     #------------------------------------------------
#     def aproxima_integral(f, a, b, eps=EPSILON):
#         '''(função, float, float, float) -> float, int
#
#         Calcula uma aproximação da integral da função f
#         no intervalo [a,b] usando um número k de retângulos
#         que seja suficiente para que obter erro relativo  menor
#         que eps.
#
#         Para melhorar o desempenho dessa função, os valores de k devem
#         dobrar a cada iteração. Ou seja, k assume valores na sequência
#         1, 2, 4, 8, 16, etc.
#
#         A função retorna 2 valores,
#
#            - o valor da aproximação e
#            - o valor de k usado para atingir essa aproximação,
#
#         nessa ordem.
#         '''
#         # corpo da função
#         [...]
#         return aproximacao, k # nomes ilustrativos

# %% [markdown]
# A função aproxima_integral() deve chamar a integral_por_retangulos(f, a, b, k) com valores de k cada vez maiores, calculado o erro relativo entre duas chamadas consecutivas, até que o erro relativo seja estritamente menor que a precisão eps desejada.
#
# Para melhorar o desempenho da função aproxima_integral(), em vez de incrementar (de 1) o valor de k a cada iteração, sua função deve dobrar o valor de k. Desta forma, k assume os valores na sequência 1, 2, 4, 8, 16, etc.
#
# Você deve usar a função erro_rel(y, x), que calcula o erro relativo de y e x, que já está implementada no arquivo ep07.py.
#
# Calculo da integral de uma função qualquer
# Observe que as duas funções que você deve implementar recebem uma função f() como argumento, da mesma forma que recebe os valores de a, b e k ou, opcionalmente, eps. Passagem de funções como argumento é um recurso de Python que vamos explorar para calcular a integral de qualquer função f(x) que recebe e retorna um valor real.
#
# Veja está simulação aqui para ajudar entender o mecanismo de passagem de uma função como parâmetro.
#
# O arquivo ep07.py contém um exemplo de função main() que mostra como utilizar as funções integral_por_retangulos() e aproxima_integral(). A função main() também mostra como fazer referência a funções definidas no próximo programa com def .... Mostra ainda como fazer referência a uma função de algum outro módulo como o math; nesse caso necessitamos adicionar uma linha com import math.
#
# O arquivo ep07.py contém ainda três funções auxiliares: f_1(x), f_2(x) e f_3(x).
# Estude essas funções para aprender a escrever suas próprias funções matemáticas de uma variável e utilize-as para testar as suas funções para cálculo da integral por retângulos.
#
# Para calcular a integral de outras funções, você deve modificar a seguinte atribuição na função main():
#
#     f_x = f_1 # f_x passa a ser um apelido da f_1
# Nessa atribuição, a variável f_x passa a fazer referência ou ser um apelido à função f_1(), que é uma das funções definidas no programa. Observe na main() como a variável f_x é passada depois nas chamadas das funções integral_por_retangulos() e aproxima_integral().
#
# A variável f_x é conveniente para que possamos testar o cálculo da integral de diferentes funções alterando apenas essa atribuição, pois poderíamos passar o valor f_1 diretamente nas chamadas como por exemplo integral_por_retangulos(f_1, 0, 1, 10) em vez de usar variáveis como em integral_por_retangulos(f_x, a, b, k).
#
# Roteiro
# Baixe o arquivo ep07.py e estude as funções nele disponíveis. Em particular, procure entender o que a função main() faz simulando-a antes de examinar os resultados abaixo. Assim, você entenderá como a variável f_x faz referência a uma função e o seu uso como argumento de outra função.
#
# Se você ainda não viu, veja está simulação aqui para ajudar entender o mecanismo de passagem de uma função como parâmetro.
#
# Depois de entender como usá-las e como elas devem de comportar, escreva as suas funções integral_por_retangulos(f, a, b, k) e aproxima_integral(f, a, b, eps).
#
# Além de aprender a passar uma função como parâmetro de outra função, vamos trabalhar nesse exercício com números em ponto flutuante e, portanto, com resultados aproximados.
#
# Esse também é um exercício de exploração do módulo math do Python, que contém várias rotinas matemáticas como math.sin(), math.cos(), math.exp(), etc.
#
# Para calcular a integral de outras funções, modifique a variável f_x na main() para fazer referência a essas outras funções, como algumas do módulo math, escrevendo por exemplo:
#
#         f_x = math.cos
#         a = 0 # experimente também outros intervalos
#         b = math.pi
# Exemplos
# Teste as funções separadamente, uma de cada vez. Você pode alterar a função main() para executar apenas os exemplos com a função integral_por_retangulos() primeiro, e só depois que essa função estiver funcionando, passe a testar as duas funções juntas.
#
# Saída para a f_1()
# Após implementar essas funções, a saída esperada da função main() com o comando f_x = f_1 é:
#
#         f_x usada nesses testes=  f_1
#         Valor de f_x(0.0)=  0.0
#         Valor de f_x(0.5)=  0.5
#         Valor de f_x(1.0)=  1.0
#
#         Integral por retângulos:
#         para 1 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.5
#         para 10 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.5000000000000001
#         para 100 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.5
#
#         Aproxima Integral:
#         para eps = 0.000001 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.500000, com 2 retângulos.
#         para eps = 0.000010 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.500000, com 2 retângulos.
#         para eps = 0.000100 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.500000, com 2 retângulos.
#         para eps = 0.001000 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.500000, com 2 retângulos.
#         Fim dos testes.
# Saída para a f_2
# A saída da função main() com o comando f_x = f_2 é:
#
#         f_x usada nesses testes=  f_2
#         Valor de f_x(0.0)=  1.0
#         Valor de f_x(0.5)=  0.8660254037844386
#         Valor de f_x(1.0)=  0.0
#
#         Integral por retângulos:
#         para 1 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.8660254037844386
#         para 10 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.7881028583154112
#         para 100 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.7854842144750019
#
#         Aproxima Integral:
#         para eps = 0.000001 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.785398, com 4096 retângulos.
#         para eps = 0.000010 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.785401, com 1024 retângulos.
#         para eps = 0.000100 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.785419, com 256 retângulos.
#         para eps = 0.001000 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.785566, com 64 retângulos.
#         Fim dos testes.
# Saída para a f_3
# A saída da função main() para f_x = f_3 é:
#
#         f_x usada nesses testes=  f_3
#         Valor de f_x(0.0)=  1.0
#         Valor de f_x(0.5)=  1.6487212707001282
#         Valor de f_x(1.0)=  2.718281828459045
#
#         Integral por retângulos:
#         para 1 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  1.6487212707001282
#         para 10 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  1.717566086461128
#         para 100 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  1.7182746689723087
#
#         Aproxima Integral:
#         para eps = 0.000001 e intervalo [0.000000, 1.000000]:
#         ---> integral = 1.718282, com 512 retângulos.
#         para eps = 0.000010 e intervalo [0.000000, 1.000000]:
#         ---> integral = 1.718277, com 128 retângulos.
#         para eps = 0.000100 e intervalo [0.000000, 1.000000]:
#         ---> integral = 1.718264, com 64 retângulos.
#         para eps = 0.001000 e intervalo [0.000000, 1.000000]:
#         ---> integral = 1.718002, com 16 retângulos.
#         Fim dos testes.
# Saída para math.cos
# A saída da função main() para f_x = math.cos é:
#
#         f_x usada nesses testes=  cos
#         Valor de f_x(0.0)=  1.0
#         Valor de f_x(0.5)=  0.8775825618903728
#         Valor de f_x(1.0)=  0.5403023058681398
#
#         Integral por retângulos:
#         para 1 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.8775825618903728
#         para 10 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.8418217000072957
#         para 100 retangulos no intervalo [0.000000, 1.000000]:
#         ---> integral:  0.841474490947226
#
#         Aproxima Integral:
#         para eps = 0.000001 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.841471, com 512 retângulos.
#         para eps = 0.000010 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.841473, com 128 retângulos.
#         para eps = 0.000100 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.841480, com 64 retângulos.
#         para eps = 0.001000 e intervalo [0.000000, 1.000000]:
#         ---> integral = 0.841608, com 16 retângulos.
#         Fim dos testes.

# %% [markdown]
# Erro Relativo
#
# Dado um número x e uma aproximação y para x, o erro, também chamado de erro absoluto, da aproximação y em relação a x é definido como sendo |y − x|. Quando a grandeza de x não é próxima de 1, o erro absoluto pode não ser a maneira mais adequada de medir a qualidade da aproximação y.
# Por exemplo, os erros absolutos de 1.01 em relação a 1.00 e de 0.02 em relação a 0.01 são idênticos, mas a nossa intuição nos diz que a primeira aproximação é muito melhor que a segunda (correto?).
#
# Face à limitada avaliação de uma aproximação conferida pelo erro absoluto, tenta-se definir o erro relativo de y em relação a x como sendo |(y − x)/x|.
#
# Assim, nos dois exemplos anteriores, os erros relativos são respectivamente de 0.01 (ou 1%) e 1 (ou 100%). Contudo, esta definição ainda é incompleta quando x = 0. Nestes casos, para se evitar a divisão por 0, adotam-se valores arbitrários para o erro relativo.
#
# No caso de também ocorrer que y = 0, a aproximação certamente é perfeita e adota-se que o erro é 0. No caso de y ≠ 0, a aproximação é certamente insatisfatória e adota-se o valor arbitrário 1 para o erro relativo. Na prática, os erros relativos procurados são sempre menores que 1.
#
# Assim, definimos
#
# erro_rel(y,x)  = 0, se x = 0 e y = 0,
# erro_rel(y,x)  = 1, se x = 0 e y ≠ 0, e
# erro_rel(y,x)  = |(y − x)/x|, se x ≠ 0.
# Aproximação da integral por erro relativo
# Vimos que, aumentando o número k de retângulos, obtemos uma melhor aproximação da integral. Mas como sabermos qual o valor de k que devemos usar para obtermos um aproximação com uma precisão desejada ou aceitável?
#
# A aceitabilidade de uma aproximação depende da aplicação. No momento vamos tomar como medida de precisão um valor pequeno que apelidaremos de EPSILON. Quanto menor EPSILON, melhor é a qualidade da aproximação.
#
# Uma forma de garantir que o valor da integral esteja dentro da precisão desejada é aumentar o valor de k até que o erro relativo entre duas aproximações sucessivas seja menor que o nosso desejo de precisão EPSILON.

# %% [markdown]
# https://www.youtube.com/watch?time_continue=2&v=TNZ7gY54EW8&feature=emb_logo
#
# http://www.mathcs.emory.edu/~cheung/Courses/170/Syllabus/07/rectangle-method.html

# %%
import math

# %%
#------------------------------------------------------------------
# Constantes que você pode utilizar nesse exercício
# Em notação científica 1.0e-6 é o o mesmo qoe 0.000001 (10 elevado a -6)
EPSILON  = 1.0e-6

#------------------------------------------------------------------
# O import abaixo carrega algumas funções do módulo math,
# associando elas a outros nomes. Assim, vc pode usar a função
# math.exp como F_EXP, math.sin como F_SIN, etc.
import math

#------------------------------------------------------------------

def main():
    '''
        Modifique essa função, escrevendo outros testes.
    '''
    # modifique a atribuição para a f_x que desejar como:
    f_x = math.cos # ou 
    # f_x = math.sin # ou
    # f_x = math.exp # etc, para integração com outras funções.
    # f_x = f_1     # a f_1, f_2, e f_3
                  # estão definidas mais abaixo.
    nome = f_x.__name__ # pega o nome da f_x usada!?

    # Testes da f_x
    print("f_x usada nesses testes= ", nome)
    print("Valor de f_x(0.0)= ", f_x( 0.0 ))
    print("Valor de f_x(0.5)= ", f_x( 0.5 ))
    print("Valor de f_x(1.0)= ", f_x( 1.0 ))

    # testes da função integral_por_retangulos
    print()
    print("Integral por retângulos:")
    # intervalo [a,b]
    a=0.0
    b=1.0
    # número de retângulos
    k = 1
    n = 3
    while n > 0:    
        print("para %d retangulos no intervalo [%f, %f]:"%(k, a, b))
        print("---> integral: ", integral_por_retangulos(f_x, a, b, k))
        k *= 10
        n -= 1

    # testes da função aproxima_integral
    print()
    print("Aproxima Integral:")
    a = 0.0
    b = 1.0
    area, k = aproxima_integral(f_x, a, b)
    print("para eps = %f e intervalo [%f, %f]:"%(EPSILON, a, b))
    print("---> integral = %f, com %d retângulos."%(area, k ))
    eps = 1e-6

    n = 3
    while n > 0: 
        eps *= 10
        area, k = aproxima_integral(f_x, a, b, eps)
        print("para eps = %f e intervalo [%f, %f]:"%(eps, a, b))
        print("---> integral = %f, com %d retângulos."%(area, k ))
        n -= 1
 
    print("Fim dos testes.")
#------------------------------------------------------------------
# FUNÇÃO AUXILIAR PARA TESTE: função linear
def f_1 ( x ):
    ''' (float) -> float 
        integral no intervalo [0, 1] -> 0.5
    '''
    return x
#------------------------------------------------------------------
# FUNÇÃO AUXILIAR PARA TESTE: função sqrt(1 - x*x)
def f_2 ( x ):
    ''' (float) -> float 
        integral no intervalo [0, 1] ~ math.pi / 4 ~ 0.7854
    '''
    y = math.sqrt( 1 - x*x )    
    return y
#------------------------------------------------------------------
# FUNÇÃO AUXILIAR PARA TESTE: função e^x
def f_3 ( x ):
    ''' (float) -> float 
        integral no intervalo [0, 1] ~ math.pi / 4 ~ 0.7854
    '''
    y = math.exp( x )
    return y
#------------------------------------------------------------------
#
def erro_rel(y, x):
    ''' (float, float) -> float
        Recebe dois números reais x e y e retorna o erro relativo entre eles.
        Exemplo:
        In  [1]: erro_rel(0, 0)
        Out [1]: 0.0
        In  [2]: erro_rel(0.01, 0)
        Out [2]: 1.0
        In  [3]: erro_rel(1.01, 1.0)
        Out [3]: 0.01
    '''
    if x == 0.0 and y == 0.0:
        return 0.0
    elif x == 0:
        return 1.0
    
    erro = (y-x)/x
    if erro < 0:
        return -erro
    return erro
#------------------------------------------------------------------
#
def integral_por_retangulos(f, a, b, k):
    '''(função, float, float, int) -> float
       Calcula uma aproximação da integral da função f
       no intervalo [a,b] usando k retângulos.
    '''
    w = (b-a)/k # width area
    i=1
    t=a
    soma = 0
    while i<=k:
        soma += w*f(t + w/2)
        t+=w
        i+=1
    return soma
    
#------------------------------------------------------------------
#
def aproxima_integral(f, a, b, eps=EPSILON):
    '''(função, float, float, float) -> float, int
       Calcula uma aproximação da integral da função f 
       no intervalo [a,b] usando o número de retângulos 
       suficiente para que o erro relativo seja menor que eps. 
       Para melhorar o desempenho dessa função, os valores de k devem 
       dobrar a cada iteração. Ou seja, k assume valores na sequência 
       1, 2, 4, 8, 16, etc.
       A função retorna 2 valores, o valor da aproximação e o valor 
       de k usado para atingir essa aproximação.
    '''
    i=0
    k=1
    while i < k:
        x = integral_por_retangulos(f, a, b, k)
        y = integral_por_retangulos(f, a, b, 2*k)
        if erro_rel(y,x) <= eps:
            return  y, 2*k# para retornar um float e um int, 
                         # basta separá-los por vírgula :-)
        k*=2
        i+=1
    
#######################################################
###                 FIM                             ###
#######################################################
# 
#  NÃO MODIFIQUE AS LINHAS ABAIXO
# 
# Esse if serve para rodar a main() dentro do Spyder
# e não atrapalhar o corretor automático         

if __name__ == '__main__':
    main()
# Out:
# f_x usada nesses testes=  cos
# Valor de f_x(0.0)=  1.0
# Valor de f_x(0.5)=  0.8775825618903728
# Valor de f_x(1.0)=  0.5403023058681397
#
# Integral por retângulos:
# para 1 retangulos no intervalo [0.000000, 1.000000]:
# ---> integral:  0.8775825618903728
# para 10 retangulos no intervalo [0.000000, 1.000000]:
# ---> integral:  0.8418217000072957
# para 100 retangulos no intervalo [0.000000, 1.000000]:
# ---> integral:  0.8414744909472259
#
# Aproxima Integral:
# para eps = 0.000001 e intervalo [0.000000, 1.000000]:
# ---> integral = 0.841471, com 512 retângulos.
# para eps = 0.000010 e intervalo [0.000000, 1.000000]:
# ---> integral = 0.841473, com 128 retângulos.
# para eps = 0.000100 e intervalo [0.000000, 1.000000]:
# ---> integral = 0.841480, com 64 retângulos.
# para eps = 0.001000 e intervalo [0.000000, 1.000000]:
# ---> integral = 0.841608, com 16 retângulos.
# Fim dos testes.

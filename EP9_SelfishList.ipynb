# %% [markdown]
# <a href="https://colab.research.google.com/github/GiuniorCandido/MAC0110/blob/master/EP9_SelfishList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objetivos
# Praticar mais ainda o uso de listas e funções com listas, especialmente, funções que modificam componentes de listas.
#
# Antes de começar
# Recomendamos a leitura das seguintes notas:
#
# Listas em Python
# Funções com listas
# Descrição
# Nesse exercício vamos continuar a praticar o uso de listas e funções com listas para a realização de experimentos para estimar probabilidades. A técnica que aplicaremos é conhecida como Método de Monte Carlo e a utilizaremos mais vezes ao longo deste ano.
#
# De volta ao grupo de amigos que organizavam o amigo secreto, eles notaram que é um certo egoísmo que na lista amigo_de[] haja um índice i tal que amigo_de[i]=i, ja que isso significaria que i daria presente para si mesm@. Chamaremos um tal índice i de egoísta.
#
# Digamos que q(N) é a probabilidade de uma permutação ou lista aleatória dos números 0, …, N − 1 não ter índices egoístas. Nesse exercício você escreverá um programa que estimará essa probabilidades. Você consegue encontrar uma fórmula fechada para essa probabilidade?
#
# Levando em conta suas descobertas, você desenvolverá também uma função que recebe uma lista de amigos com índices egoístas e transforma a lista em uma sem egoísmo. É desejável que essa transformação seja feita de maneira rápida.
#
# Antes de continuarmos, examinemos alguns exemplos para entendermos essa melhor essa tal probabilidade. Para N = 2 as permutações de 0 e 1 são [0, 1] e [1, 0]. Como apenas [1, 0] não tem índice egoísta, então q(2) = 1/2 = 0.5. Para N = 3 há 6 permutações de 0, 1 e 2 que são [0, 1, 2], [0, 2, 1], [1, 0, 2], [1, 2, 0], [2, 0, 1], [2, 1, 0]. Dentre essas, as permutações sem índices egoístas são [1, 2, 0] e [2, 0, 1]. Logo, q(3) = 2/6 = 1/3 = 0.333333…. Para N = 4 as coisas já começam a ficar cansativas para listarmos todas as permutações de 0, 1, 2 e 3… mas vamos em frente… As permutações de 0, 1, 2 e 3 são
#
#    [0, 1, 2, 3], [0, 1, 3, 2], [0, 2, 1, 3], [0, 2, 3, 1], [0, 3, 1, 2], [0, 3, 2, 1],
#    [1, 0, 2, 3], [1, 0, 3, 2], [1, 2, 0, 3], [1, 2, 3, 0], [1, 3, 0, 2], [1, 3, 2, 0],
#    [2, 0, 1, 3], [2, 0, 3, 1], [2, 1, 0, 3], [2, 1, 3, 0], [2, 3, 0, 1], [2, 3, 1, 0],
#    [3, 0, 1, 2], [3, 0, 2, 1], [3, 1, 0, 2], [3, 1, 2, 0], [3, 2, 0, 1], [3, 2, 1, 0].
# Dentre essas permutações as que não tem índices egoístas são
#
#    [1, 0, 3, 2], [1, 2, 3, 0], [1, 3, 0, 2], [2, 0, 3, 1], [2, 3, 0, 1],
#    [2, 3, 1, 0], [3, 0, 1, 2], [3, 2, 0, 1], [3, 2, 1, 0].
# Portanto, q(4) = 9/24 = 3/8 = 0.375.
#
# O número de possíveis permutações cresce muito a medida que N cresce. Por exemplo, se o número de N de amigos fosse 45, então teríamos
#
#     45! = 2.658.271.574.788.448.768.043.625.811.014.615.890.319.638.528.000.000.000
# permutações para examinarmos a fim de obtermos o valor de q(45). Bem, esse número é maior que o número estimado de átomos na Terra
#
#                 133.000.000.000.000.000.000.000.000.000.000.000.000.000.000.000.000
# segundo How many atoms are there in the world?. Uaaauuuu! Pois é, esse número é absurdamente grande para gerarmos todas as listas e contarmos quantas não possuem índices egoístas. Aqui é o momento que apelamos para estatística com o seu Método de Monte Carlo e passamos a estimar q(N) em vez de calcularmos exatamente.

# %% [markdown]
# O que você deve fazer
# Você deve completar o programa no arquivo ep09.py que estima a probabilidade q(N) para vários valores de N.
#
# O arquivo ep09.py contém uma função main() para lhe ajudar com os testes. Há ainda uma função sorteie_lista(), idêntica a do EP08, que cria e retorna uma lista embaralhada/aleatória.
#
# Para vários valores de N, a função main() realiza experimentos a fim de estimar a probabilidade q(N).
#
# Cada experimento consiste de T tentativas. Em cada tentativa é sorteada uma lista embaralhada de comprimento N contendo os valores 0, 1, …, N-1.
#
# Se S é o número das listas sorteadas que não possuem índices egoístas, então a razão S/T será a estimativa obtida para a probabilidade q(N).
#
# Funções main() e sorteie_lista()
# As função main() e sorteie_lista() estão disponíveis no arquivo ep09.py. No entanto, elas tem problemas e deverão ser consertadas antes que possam ser utilizadas.
#
# main(): a tabulação de suas linhas foi removida. Portanto, antes de utilizá-la, você deverá corrigir essa tabulação.
#
# sorteie_lista(N): cria e retorna uma lista de tamanho N contendo uma permutação dos números 0, 1, …, N-1. A tabulação de suas linhas foi removida e algumas linhas foram invertidas. Você deve colocar a linhas dessa função na ordem certa e corrigir a tabulação.
#
# Não altere nada além da tabulação da função main(). Isso deve fortalecer a sua compreensão sobre blocos de comandos (= trecho de código depois de :) em whiles, ifs, elifs, defs, etc.
#
# Não altere nada além da ordem das linhas e a tabulação da função sorteie_lista(). Isso deve fortalecer a sua compreensão sobre a ordem e blocos de comandos.
#
# Para fazer esses consertos, examine o comportamento dessas funções nos exemplos mais adiante.
#
# Funções no_egoistas(), experimento() e altruistas()
# Neste EP você deve implementar as funções no_egoistas(), experimento() e altruistas() como especificado abaixo.
#
# no_egoistas(amigo_de): recebe uma lista amigo_de e retorna o número de índices egoístas na lista.
#
# experimento(N, T): recebe dois inteiros, N e T. A função realiza T sorteios de listas aleatórias de tamanho N contendo os inteiros 0, 1, …, N-1. A função retorna uma estimativa para probabilidade q(N) de uma lista de tamanho N não possuir índices egoístas. Essa estimativa é razão S/T entre o número observado de listas sem índices egoístas e o número T de listas sorteadas. Assim, por exemplo, se T  = 100 e observamos que dentre as T listas sorteadas há S = 15 que não possuem índices egoístas, então a estimativa para probabilidade será S/T = 15/100 = 0.15. A função deve retornar a estimativa para q(N) e uma lista com todas as listas sorteadas que possuiam índices egoístas.
#
# altruistas(amigo_de): recebe uma lista amigo_de com índices egoístas e transforma essa lista em uma lista sem índices egoístas. Essa função altera a lista recebida e retorna None. Se você está em busca de inspiração para escrever essa função estude os exemplos a seguir e, se desejar implemente a mesma estratégia ou ainda qualquer outra que preferir.

# %% [markdown]
# Exemplos
# A seguir estão alguns exemplos de execução do programa. Valores em vermelho foram digitados pelo usuário:
#
# Exemplo 1
# Comece testando seu programa com exemplos simples, pequenos, e confira que os resultados estão corretos. Como no EP08, use uma mesma semente para testar e garantir reprodutibilidade. Estude a função main() para corrigir sua tabulação e identifique os trechos para teste das funções no_egoistas(), experimento() e altruistas() com uma lista grande. Nos testes do experimento, a main() pode exibir o resultado antes e depois de cada chamada da função altruistas() com as listas com índices egoístas produzidas durante os experimentos.
#
#         Testes para o EP09
#
#         Teste no_egoistas()
#             no_egoistas([1, 2, 3, 4, 0]) = 0
#             no_egoistas([2, 1, 0, 3, 4]) = 3
#         Digite o valor da semente do gerador de números pseudo-aleatórios: 123
#
#         Parâmetros para o experimento
#         Digite o número mínimo de pessoas: 4
#         Digite o número máximo de pessoas: 12
#         Digite o passo: 4
#         Digite o número de tentativas em cada experimento: 10
#         Deseja ver as listas com índices egoistas [s/n]: s
#         Teste experimento()
#         q(4) = 0.400000
#             lista com índices egoistas para q(4):
#             antes :  [2, 0, 1, 3]
#             depois:  [3, 0, 1, 2]
#             antes :  [0, 2, 3, 1]
#             depois:  [2, 0, 3, 1]
#             antes :  [2, 1, 0, 3]
#             depois:  [3, 0, 1, 2]
#             antes :  [2, 1, 3, 0]
#             depois:  [2, 3, 1, 0]
#             antes :  [1, 2, 0, 3]
#             depois:  [3, 2, 0, 1]
#             antes :  [1, 3, 2, 0]
#             depois:  [1, 3, 0, 2]
#             tempo decorrido:    0.88 ms
#         q(8) = 0.200000
#             lista com índices egoistas para q(8):
#             antes :  [5, 1, 4, 3, 7, 0, 6, 2]
#             depois:  [5, 4, 1, 7, 3, 0, 2, 6]
#             antes :  [5, 1, 6, 7, 2, 0, 3, 4]
#             depois:  [5, 6, 1, 7, 2, 0, 3, 4]
#             antes :  [7, 1, 0, 2, 5, 4, 6, 3]
#             depois:  [7, 0, 1, 2, 5, 4, 3, 6]
#             antes :  [0, 1, 2, 3, 7, 4, 5, 6]
#             depois:  [1, 0, 3, 2, 7, 4, 5, 6]
#             antes :  [5, 1, 0, 3, 4, 6, 7, 2]
#             depois:  [5, 0, 1, 4, 3, 6, 7, 2]
#             antes :  [4, 6, 7, 3, 1, 2, 0, 5]
#             depois:  [4, 6, 7, 1, 3, 2, 0, 5]
#             antes :  [7, 2, 0, 6, 1, 5, 3, 4]
#             depois:  [7, 2, 0, 6, 1, 3, 5, 4]
#             antes :  [2, 1, 5, 4, 0, 6, 3, 7]
#             depois:  [7, 5, 1, 4, 0, 6, 3, 2]
#             tempo decorrido:    1.03 ms
#
#         Teste altruismo() para lista grande
#             no. de egoístas com lista de 1000000 = 1
#             no. de egoístas com lista de 1000000 = 0
#             tempo decorrido:  180.74 ms
# Exemplo 2
# O Exemplo 2 usa os mesmos parâmetros de entrada (digitados pelo usuário) que o Exemplo 1, mas usa uma semente diferente. Assim, dada a natureza aleatória dos resultados, as probabilidades calculadas para cada N podem ser diferentes em cada experimento, já que as listas sorteadas são diferentes.
#
#        Testes para o EP09
#
#        Teste no_egoistas()
#            no_egoistas([1, 2, 3, 4, 0]) = 0
#            no_egoistas([2, 1, 0, 3, 4]) = 3
#        Digite o valor da semente do gerador de números pseudo-aleatórios: 321
#
#        Parâmetros para o experimento
#        Digite o número mínimo de pessoas: 4
#        Digite o número máximo de pessoas: 13
#        Digite o passo: 4
#        Digite o número de tentativas em cada experimento: 10
#        Deseja ver as listas com índices egoistas [s/n]: s
#        Teste experimento()
#        q(4) = 0.400000
#            lista com índices egoistas para q(4):
#            antes :  [0, 1, 3, 2]
#            depois:  [1, 0, 3, 2]
#            antes :  [0, 2, 1, 3]
#            depois:  [3, 0, 1, 2]
#            antes :  [1, 2, 0, 3]
#            depois:  [3, 2, 0, 1]
#            antes :  [0, 1, 2, 3]
#            depois:  [1, 0, 3, 2]
#            antes :  [0, 2, 3, 1]
#            depois:  [2, 0, 3, 1]
#            antes :  [3, 1, 0, 2]
#            depois:  [3, 0, 1, 2]
#            tempo decorrido:    1.25 ms
#        q(8) = 0.100000
#            lista com índices egoistas para q(8):
#            antes :  [4, 6, 0, 3, 1, 2, 5, 7]
#            depois:  [7, 6, 0, 1, 3, 2, 5, 4]
#            antes :  [7, 0, 4, 2, 3, 1, 6, 5]
#            depois:  [7, 0, 4, 2, 3, 1, 5, 6]
#            antes :  [4, 0, 1, 3, 2, 7, 6, 5]
#            depois:  [4, 0, 1, 2, 3, 7, 5, 6]
#            antes :  [6, 7, 3, 0, 4, 1, 2, 5]
#            depois:  [6, 7, 3, 0, 1, 4, 2, 5]
#            antes :  [0, 2, 1, 3, 4, 5, 6, 7]
#            depois:  [7, 0, 1, 4, 3, 6, 5, 2]
#            antes :  [6, 1, 0, 3, 2, 4, 7, 5]
#            depois:  [6, 0, 1, 2, 3, 4, 7, 5]
#            antes :  [6, 3, 5, 2, 1, 4, 0, 7]
#            depois:  [7, 3, 5, 2, 1, 4, 0, 6]
#            antes :  [3, 0, 2, 4, 6, 5, 7, 1]
#            depois:  [3, 0, 4, 2, 6, 7, 5, 1]
#            antes :  [1, 3, 6, 2, 4, 7, 0, 5]
#            depois:  [1, 3, 6, 2, 7, 4, 0, 5]
#            tempo decorrido:    1.95 ms
#        q(12) = 0.300000
#            lista com índices egoistas para q(12):
#            antes :  [7, 1, 3, 0, 2, 11, 6, 9, 5, 8, 10, 4]
#            depois:  [7, 3, 1, 0, 2, 11, 9, 6, 5, 8, 4, 10]
#            antes :  [3, 6, 2, 9, 11, 8, 0, 4, 7, 10, 5, 1]
#            depois:  [3, 6, 9, 2, 11, 8, 0, 4, 7, 10, 5, 1]
#            antes :  [10, 0, 9, 8, 6, 2, 3, 7, 5, 4, 1, 11]
#            depois:  [11, 0, 9, 8, 6, 2, 3, 5, 7, 4, 1, 10]
#            antes :  [0, 11, 6, 5, 1, 4, 10, 8, 3, 7, 2, 9]
#            depois:  [11, 0, 6, 5, 1, 4, 10, 8, 3, 7, 2, 9]
#            antes :  [1, 0, 4, 7, 11, 6, 5, 3, 10, 9, 2, 8]
#            depois:  [1, 0, 4, 7, 11, 6, 5, 3, 10, 2, 9, 8]
#            antes :  [4, 7, 8, 3, 6, 11, 9, 5, 0, 2, 10, 1]
#            depois:  [4, 7, 8, 6, 3, 11, 9, 5, 0, 2, 1, 10]
#            antes :  [7, 4, 2, 11, 8, 1, 5, 9, 6, 0, 10, 3]
#            depois:  [7, 4, 11, 2, 8, 1, 5, 9, 6, 0, 3, 10]
#            tempo decorrido:    1.00 ms
#
#        Teste altruismo() para lista grande
#            no. de egoistas com lista de 1000000 = 3
#            no. de egoistas com lista de 1000000 = 0
#            tempo decorrido:  174.00 ms
# Exemplo 3
# O exemplo 3 não exibe as listas com índices egoístas e suas transformações. O programa cronometra e exibe o tempo gasto pelo computador para calcular alguns dos resultados. Isso foi feito usando a função time.time() do módulo time do Python.
#
#         Testes para o EP09
#
#         Teste no_egoistas()
#             no_egoistas([1, 2, 3, 4, 0]) = 0
#             no_egoistas([2, 1, 0, 3, 4]) = 3
#         Digite o valor da semente do gerador de números pseudo-aleatórios: 86
#
#         Parâmetros para o experimento
#         Digite o número mínimo de pessoas: 10
#         Digite o número máximo de pessoas: 101
#         Digite o passo: 10
#         Digite o número de tentativas em cada experimento: 1000
#         Deseja ver as listas com índices egoistas [s/n]: n
#         Teste experimento()
#         q(10) = 0.390000
#             tempo decorrido:   37.12 ms
#         q(20) = 0.353000
#             tempo decorrido:   19.35 ms
#         q(30) = 0.361000
#             tempo decorrido:   27.04 ms
#         q(40) = 0.379000
#             tempo decorrido:   37.00 ms
#         q(50) = 0.367000
#             tempo decorrido:   49.05 ms
#         q(60) = 0.363000
#             tempo decorrido:   52.79 ms
#         q(70) = 0.349000
#             tempo decorrido:   59.57 ms
#         q(80) = 0.380000
#             tempo decorrido:   67.06 ms
#         q(90) = 0.344000
#             tempo decorrido:   75.13 ms
#         q(100) = 0.376000
#             tempo decorrido:   85.84 ms
#
#         Teste altruismo() para lista grande
#             no. de egoístas com lista de 1000000 = 2
#             no. de egoístas com lista de 1000000 = 0
#             tempo decorrido:  179.55 ms
# Exemplo 4
# Semelhante ao exemplo 3, com valores distintos. Observe que com T = 10000, o tempo gasto para estimarr q(100) foi aproximadamente 10 vezes maior que no exemplo 3. Apesar do valor numérico do tempo gasto depender da máquina utilizada, ele é um indicador da eficiência do programa.
#
#         Testes para o EP09
#
#         Teste no_egoistas()
#             no_egoistas([1, 2, 3, 4, 0]) = 0
#             no_egoistas([2, 1, 0, 3, 4]) = 3
#         Digite o valor da semente do gerador de números pseudo-aleatórios: 99
#
#         Parâmetros para o experimento
#         Digite o número mínimo de pessoas: 100
#         Digite o número máximo de pessoas: 1001
#         Digite o passo: 100
#         Digite o número de tentativas em cada experimento: 10000
#         Deseja ver as listas com índices egoistas [s/n]: n
#         Teste experimento()
#         q(100) = 0.361500
#             tempo decorrido:  837.16 ms
#         q(200) = 0.370000
#             tempo decorrido: 1585.14 ms
#         q(300) = 0.364800
#             tempo decorrido: 2464.17 ms
#         q(400) = 0.365400
#             tempo decorrido: 3363.58 ms
#         q(500) = 0.370600
#             tempo decorrido: 4146.45 ms
#         q(600) = 0.352900
#             tempo decorrido: 5206.35 ms
#         q(700) = 0.367400
#             tempo decorrido: 6048.02 ms
#         q(800) = 0.376100
#             tempo decorrido: 6889.65 ms
#         q(900) = 0.375200
#             tempo decorrido: 7861.94 ms
#         q(1000) = 0.367900
#             tempo decorrido: 8751.92 ms
#
#         Teste altruismo() para lista grande
#             no. de egoístas com lista de 1000000 = 3
#             no. de egoístas com lista de 1000000 = 0
#             tempo decorrido:  178.63 ms

# %%
#####################################################################
# MÓDULOS A SEREM UTILIZADOS NO PROGRAMA
# random.shuffle()
import random

# time.time()
import time 

#-----------------------------------------------------------------------
def main():
    '''(None) -> None

        Unidade de teste para as funções pedidas no EP.
        Escreva outros testes que desejar.
        '''
    print("Testes para o EP09")

    # testes da função no_egoistas
    print()
    print("Teste no_egoistas()")
    amigos1 = [1,2,3,4,0]
    amigos2 = [2,1,0,3,4]
    print("    no_egoistas(%s) = %s"%(amigos1, no_egoistas(amigos1)))
    print("    no_egoistas(%s) = %s"%(amigos2, no_egoistas(amigos2)))

    # para efeito de reprodutibilidade dos experimentos
    semente = int(input("Digite o valor da semente do gerador de números pseudo-aleatórios: "))
    random.seed(semente)

    # parâmetros para os experimentos
    print() # pula linha
    print("Parâmetros para o experimento ")
    ini    = int(input("Digite o número mínimo de pessoas: "))
    fim    = int(input("Digite o número máximo de pessoas: "))
    passo  = int(input("Digite o passo: "))
    T      = int(input("Digite o número de tentativas em cada experimento: "))
    mostre = input("Deseja ver as listas com índices egoistas [s/n]: ")

    print("Teste experimento()")
    # estima q(N) para vários valores de N
    for N in range(ini, fim, passo):
        # inicie o cronômetro
        t_ini = time.time()
        # execute o experimento
        qN, lst_egoistas = experimento(N, T)
        # exiba a estimativa do valor de q(N)
        print("q(%d) = %f"%(N, qN))
        if mostre in ['s', 'S']: 
            print("    lista com índices egoistas para q(%d): "%(N))
            tamanho = len(lst_egoistas)
            if tamanho == 0:
                print("      nenhuma lista possui índice esgoísta")
            else:
                # transforme listas com egoistas em listas sem 
                for i in range(0, tamanho, 1):
                    print("    antes : ", lst_egoistas[i])
                    altruistas(lst_egoistas[i])
                    print("    depois: ", lst_egoistas[i])
        # pare cronômetro            
        t_fim = time.time()
        print("    tempo decorrido: %7.2f ms"%((t_fim - t_ini)*1000))
    print()    
    # teste altruismo() n grande
    print("Teste altruismo() para lista grande")
    muito_grande = 1000000
    amigos3  = sorteie_lista(muito_grande)
    amigos3 += [muito_grande] # garante índice egoísta
    print("    no. de egoístas com lista de %d = %s"%(muito_grande, no_egoistas(amigos3)))
    t_ini = time.time() # inicie o cronômetro
    altruistas(amigos3)
    t_fim = time.time() # pare cronômetro 
    print("    no. de egoístas com lista de %d = %s"%(muito_grande, no_egoistas(amigos3)))
    print("    tempo decorrido: %7.2f ms"%((t_fim - t_ini)*1000))

#-----------------------------------------------------------------------
def sorteie_lista(n):
    '''(int) -> list

    RETORNA uma lista de tamanho n, contendo os números de 0 a n em 
    ordem aleatória.

    ATENÇÃO: a tabulação das linhas foi removida e a ordem de algumas 
    linhas alterada. A função deve ser consertada antes de ser utilizada.
    '''
    lista = []
    for i in range(n):
        lista += [i]
    random.shuffle(lista)   
    return lista
#-----------------------------------------------------------------------
def no_egoistas(amigo_de):
    '''(list) -> int

    RECEBE uma lista `amigo_de`.
    RETORNA o número de indices egoistas na lista.
    '''
    k = 0
    for w in range(len(amigo_de)):
        if amigo_de[w] == w:  
            k += 1   
    return k
   

#-----------------------------------------------------------------------
def experimento(N, T):
    '''(int, int) -> float, list

    RECEBE um inteiros positivos N e T.

    Estima a probabilidade q(N) de uma lista de "amigo secreto" 
    com N participantes NÃO ter um índice esgoista.

    A função realiza T sorteios de listas de tamanha N e utiliza 
    como estimador a razão entre o número de listas sem egoistas e T.

    RETORNA a probabilidade estimada para q(N) e uma lista formada
    por todas as listas com índices egoístas sorteadas durante 
    o experimento.
    '''
    lista1 = []
    k = 0
    for i in range(T):
        lista2 = sorteie_lista(N)
        if no_egoistas(lista2) == 0:
            k+=1
        else:
            lista1 += [lista2]
    return k / T, lista1 # retorna uma estimativa probabilidade e uma lista de listas
#-----------------------------------------------------------------------
def altruistas(amigo_de):
    ''' (list) -> None

    RECEBE uma lista amigo_de e troca a posição de elementos da lista
    de tal forma a não possuir índices egoístas.
    '''
    k = len(amigo_de)  
    if k != 1:
        while no_egoistas(amigo_de) != 0:
             random.shuffle(amigo_de)
    return None

#=====================================================================
# Não modifique as linhas abaixo
# Esse if serve para rodar a main() dentro do Spyder
# e não atrapalhar o corretor automático
if __name__ == '__main__':
    main()

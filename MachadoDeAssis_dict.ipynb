# %% [markdown]
# <a href="https://colab.research.google.com/github/GiuniorCandido/MAC0110/blob/master/MachadoDeAssis_dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objetivo
# Aprender e aplicar conceitos de dicionários, a estrutura de dados mais importante do universo (nada como exagerar par achamar a atenção sorriso). Com auxílio de dicionários extraíremos a essência estatística de textos para “reencarnar” Machado de Assis e escrever versos “similares” (do ponto de vista estatítico piscando) ao do escritor.
#
# Em relação aos recursos de Python trabalhados nesse EP recomendamos a leitura das seguintes notas:
#
# Dicionários
# Funções com listas
# Strings e Arquivos
# Neste EP serão visitados alguns poucos conceitos de linguítica de corpus. Linguística de corpus (ou córpus) se ocupa da coleta e análise de corpus, que é um conjunto de amostras linguísticas coletadas criteriosamente para serem objeto de pesquisa. No nosso caso o corpus será formado por textos de Machado de Assis.
#
# No que segue escreveremos item léxico, ou simplemente, item para nos referirmos a qualquer palavra ou sinais de pontuação nos textos de Machado de Assis que utilizaremos.
#
# Este exercício programa foi baseado neste outro exercício programa da Universidade de Berkeley.
#
# Apresentação
# Machado de Assis é considerado por muitos o maior nome da literatura brasileira. Nascido no Rio de Janeiro em 21 de junho de 1839, é autor de obras marcantes como Memorias Póstumas de Brás Cubas, Dom Casmurro, O Alienista etc.
#
# Neste EP, vamos escrever um programa que realiza a mimesis do trabalho de Machado, escrevendo frases que estatísticamente se assemelham com as frases escritas por ele. Mas antes, vamos tratar um pouco sobre dicionários.
#
# Dicionários
# Um dicionário é um conjunto de objetos cada um dotado de uma chave e de um valor.
#
# As chaves podem ser números inteiros ou strings ou alguns outros tipos de dados, todos imutáveis. Os valores podem ser inteiros ou strings ou listas ou qualquer outro tipo de dados.
#
# Um dicionário está sujeito a dois tipos de operações:
#
# inserção: consiste em introduzir um para chave-valor na tabela
# busca: consiste em encontrar o valor associado a uma dada chave.
# Essencialmente, um dicionário é uma tabela com duas colunas: uma coluna de chaves e uma de valores. Para criar um dicionário de nome dicio vazio escrevemos:
#
#     In  [1]: dicio = {}
# Já para criarmos um dicionário com alguns valores escrevemos:
#
#     In  [2]: coletivo = {'abelha': 'colmeia', 'peixe': 'cardume'}
# Acabamos de criar um dicionário chamado coletivo. O que está dentro de {} representam os pares pares chave-valor do dicionário. Cada par é separado por uma vírgula, e para cada par a chave vem antes de : e seu correspondente valor vem depois de :. No nosso caso, abelha e peixe são as chaves e os valores são colmeia e cardume.
#
# Você pode ter acesso ao valor de uma chave de uma forma que lembra índices de lista ou strings:
#
#     In  [3]: coletivo['abelha']
#     Out [3]: 'colmeia'
#
#     In  [4]: coletivo['peixe']
#     Out [4]: 'cardume'
# Ademais, é possível alterar o valor de uma chave da seguinte maneira:
#
#     In  [5]: coletivo['abelha'] = 'Colmeia'
# Finalmente, você pode adicionar um novo par chave-valor da seguinte forma:
#
#     In  [6]: coletivo['montanha'] = 'cordilheira'
#
#     In  [7]: coletivo['montanha']
#     Out [7]: 'cordilheira'
# Machado e dicionários
# Agora que você sabe como os dicionários funcionam, podemos tratar do próximo passo — usar a obra de Machado para estatísticamente “imitar” seu trabalho.
#
# A ideia é a seguinte. Tomamos uma palavra inicial como, por exemplo, 'olá'. Em seguida, olhamos toda a obra de Machado e em cada ocorrência da palavra 'olá', nós pegamos o item, palavra ou sinais de pontuação, que aparece logo em seguida e colocamos este item em uma lista. Vamos chamar essa lista de lista (de itens) sucessores de 'olá'. Suponha que tenhamos feito isso para toda palavra que Machado já escreveu.
#
# Voltemos para a palavra 'olá'. Agora, escolhemos aleatoriamente um item na lista sucessores de 'olá'. Vamos supor que esse item seja a palavra 'mundo'. Escolhemos, aleatoriamente, um item na lista de sucessores de 'mundo'. Continuamos este processo aleatório até chegarmos em um '.' ou '!' ou '?'. Neste momento, teremos gerado uma frase utilizando como base as listas de sucessores obtidos da obra de Machado.
#
# Neste EP essas listas de sucessores serão representadas por um dicionário de sucessores. Neste dicionário, as chaves serão itens (palavras ou sinais de pontuação). O valor correspondente a cada chave será a listas dos itens que aparecem em um dado texto imediatamente após a chave. Para ter uma ideia, para o texto “MAC0110! É, muito, dá hora!” o dicionário será:
#
#     {'!'      : ['MAC0110', 'É'],
#      ','      : ['muito', 'dá'],
#      'MAC0110': ['!'],
#      'dá'     : ['hora'],
#      'hora'   : ['!'],
#      'muito'  : [','],
#      'É'      : [',']
#      }
# Convencionaremos que um sucessor do último item ('!') será o primeiro ('MAC0110').
#
# Construção do dicionário de sucessores
# Para construir o dicionário de sucessores, você deverá escrever a função dicio_sucessores() como especificada no arquivo ep14.py. Essa função recebe uma lista com itens na ordem em que aparecem em um dado texto. Por exemplo, para
#
#     In  [5]: texto = "eu gosto de olhos que sorriem, de gestos que se desculpam, de toques que sabem conversar e de silêncios que se declaram."
# teremos que a lista correspondente será
#
#     In  [6]: lst = ['eu', 'gosto', 'de', 'olhos', 'que', 'sorriem', ',', 'de', 'gestos',
#           'que', 'se', 'desculpam', ',', 'de', 'toques', 'que', 'sabem',
#           'conversar', 'e', 'de', 'silêncios', 'que', 'se', 'declaram', '.']
# e ao aplicarmos a função dicio_sucessores(lst) obteremos
#
#     In  [7]: dicio = dicio_sucessores(lst)
#
#     In  [8]: dicio
#     Out [8]:
#     {'.': ['eu'], 'eu': ['gosto'], 'gosto': ['de'],
#      'de': ['olhos', 'gestos', 'toques', 'silêncios'], 'olhos': ['que'],
#      'que': ['sorriem', 'se', 'sabem', 'se'], 'sorriem': [','],
#      ',': ['de', 'de'], 'gestos': ['que'], 'se': ['desculpam', 'declaram'],
#      'desculpam': [','], 'toques': ['que'], 'sabem': ['conversar'],
#      'conversar': ['e'], 'e': ['de'], 'silêncios': ['que'], 'declaram': ['.']}
# Processo aleatório para gerar frases
# Para gerar frases você deverá escrever a função gere_frase() que está especificada no arquivo ep14.py. Essa função recebe uma palavra inicial e um dicionário de sucessores correspondente a um dado texto.
#
# Suponha que palavra inicial é uma chave do dicionário. Para gerar uma frase a função executa o seguinte processo aleatório.
#
# Coloca a chave no final da frase que está sendo gerada. Em seguida, examina no dicionário o valor correspondente a essa chave, obtendo assim a lista dos itens sucessores da chave. Depois, seleciona aleatoriamente um item dessa lista para ser a nova chave. O processo é repetido com a nova chave no papel da antiga.
#
# A função deve repetir o processo acima até chegar a um item que seja uma pontuação final, ou seja, um caractere em ".!?".
#
# A fim de selecionar aleatóriamente um item de uma lista lst de sucessores de uma chave utilize a função random.choice(lst).
#
# O que deve ser feito
# Primeiro você deve baixar o arquivo ep14.py que contém as especificações das três funções que você deverá escrever nesse EP: insira_espacos(), dicio_sucessoras() e gere_frase().
#
# Em seguida, escreva e teste, uma a uma, essas funções.
#
# Depois de testar suas funções você pode executar a função main() que vem no ep14.py. Para isso você pode utilizar os seguintes textos de Machado de Assis: O Almada, Dom Casmurro, Memórias Póstumas de Brás Cubas, e Quincas Borba. Esse textos podem ser baixados daqui junto com o arquivo tudo.txt que é uma compilação de todos esses textos.

# %% [markdown]
# Exemplos
# Use os exemplos de saída abaixo para testar suas funções.
#
# insira_espacos()
#     In [2]: texto1 = "MAC0110! É, muito, dá hora!"
#
#     In [3]: novo_texto1 = insira_espacos(texto1)
#
#     In [4]: novo_texto1
#     Out[4]: 'MAC0110 !  É ,  muito ,  dá hora ! '
#
#     In [5]: texto2 = "— Continue, disse eu acordando."
#
#     In [6]: novo_texto2 = insira_espacos(texto2)
#
#     In [7]: novo_texto2
#     Out[7]: ' —  Continue ,  disse eu acordando . '
#
#     In [9]: texto3 = 'Rubião achou um rival no coração de Quincas Borba — um cão, um bonito cão, meio tamanho, pêlo cor de chumbo, malhado de preto.'
#
#     In [10]: novo_texto3 = insira_espacos(texto3)
#
#     In [11]: novo_texto3
#     Out[11]: 'Rubião achou um rival no coração de Quincas Borba  —  um cão ,  um bonito cão ,  meio tamanho ,  pêlo cor de chumbo ,  malhado de preto . '
# dicio_sucessores()
#     In [12]: lst1 = novo_texto1.split()
#
#     In [13]: lst1
#     Out[13]: ['MAC0110', '!', 'É', ',', 'muito', ',', 'dá', 'hora', '!']
#
#     In [14]: dicio1 = dicio_sucessores(lst1)
#
#     In [15]: dicio1
#     Out[15]:
#     {'!': ['MAC0110', 'É'],
#      ',': ['muito', 'dá'],
#      'MAC0110': ['!'],
#      'dá': ['hora'],
#      'hora': ['!'],
#      'muito': [','],
#      'É': [',']}
#
#     In [16]: lst2 = novo_texto2.split()
#
#     In [17]: lst2
#     Out[17]: ['—', 'Continue', ',', 'disse', 'eu', 'acordando', '.']
#
#     In [18]: dicio2 = dicio_sucessores(lst2)
#
#     In [19]: dicio2
#     Out[19]:
#     {',': ['disse'],
#      '.': ['—'],
#      'Continue': [','],
#      'acordando': ['.'],
#      'disse': ['eu'],
#      'eu': ['acordando'],
#      '—': ['Continue']}
#
#     In [20]: lst3 = novo_texto3.split()
#
#     In [21]: lst3
#     Out[21]:
#     ['Rubião',
#      'achou',
#      'um',
#      'rival',
#      'no',
#      'coração',
#      'de',
#      'Quincas',
#      'Borba',
#      '—',
#      'um',
#      'cão',
#      ',',
#      'um',
#      'bonito',
#      'cão',
#      ',',
#      'meio',
#      'tamanho',
#      ',',
#      'pêlo',
#      'cor',
#      'de',
#      'chumbo',
#      ',',
#      'malhado',
#      'de',
#      'preto',
#      '.']
#
#     In [22]: dicio3 = dicio_sucessores(lst3)
#
#     In [23]: dicio3
#     Out[23]:
#     {',': ['um', 'meio', 'pêlo', 'malhado'],
#      '.': ['Rubião'],
#      'Borba': ['—'],
#      'Quincas': ['Borba'],
#      'Rubião': ['achou'],
#      'achou': ['um'],
#      'bonito': ['cão'],
#      'chumbo': [','],
#      'cor': ['de'],
#      'coração': ['de'],
#      'cão': [',', ','],
#      'de': ['Quincas', 'chumbo', 'preto'],
#      'malhado': ['de'],
#      'meio': ['tamanho'],
#      'no': ['coração'],
#      'preto': ['.'],
#      'pêlo': ['cor'],
#      'rival': ['no'],
#      'tamanho': [','],
#      'um': ['rival', 'cão', 'bonito'],
#      '—': ['um']}
# gere_frase()
# A função gere_frase() utiliza o módulo random e em particupar random.choice(lst). Por essa razão, a seguir fazemos
#
#     In [ ]: import random
#
#     In [ ]: random.seed(1234)
# a fim de tentar obter reprodutibilidade dos resultados. Mesmo assim, algumas frases geradas pela sua função podem ser diferentes das mostradas a seguir.
#
#     In [24]: dicio1 = {'!': ['Como'],'Como': ['é'],'MAC0110': ['!'],'bom': ['estudar'],
#     'estudar': ['MAC0110'],'é': ['bom']}
#
#     In [25]: gere_frase('Como', dicio1)
#     Out[25]: 'Como é bom estudar MAC0110!'
#
#     In [26]: gere_frase('é', dicio1)
#     Out[26]: 'é bom estudar MAC0110!
#
#     In [27]: import random
#
#     In [28]: random.seed(1234) # para reprodutibilidade
#
#     In [29]:  dicio2 = {'!': ['MAC0110', 'É'], ',': ['muito', 'dá'],'MAC0110': ['!'],'dá': ['hora'], 'hora': ['!'], 'muito': [','], 'É': [',']}
#
#     In [30]: gere_frase('MAC0110', dicio2)
#     Out[30]: 'MAC0110!'
#
#     In [31]: gere_frase('dá', dicio2)
#     Out[31]: 'dá hora!'
#
#     In [32]: gere_frase('muito', dicio2)
#     Out[32]: 'muito, muito, muito, muito, muito, dá hora!'
#
#     In [33]: random.seed(1234)
#
#     In [34]: gere_frase("um", dicio3)
#     Out[34]: 'um cão, um rival no coração de chumbo, um rival no coração de preto.'
#
#     In [35]: gere_frase("Quincas", dicio3)
#     Out[35]: 'Quincas Borba — um bonito cão, malhado de Quincas Borba — um bonito cão, um bonito cão, pêlo cor de preto.'
# main()
# A função main() lê textos e gera frases baseadas no dicionário de sucessores construído a partir de um texto.
#
# Quincas Borba
#
#     ESCREVENDO "como" MACHADO DE ASSIS!
#
#     Digite o nome do arquivo com o texto: quincas.txt
#     Digite o numero de frases que devem ser geradas: 4
#     ---
#     Digite a palavra inicial da frase 1: Um
#     Frase gerada: Um queria entrar as admirações colhidas, e deu-lhe um cacete, e a outra vez mais propriamente, após o que até à sala, há de ouro.
#     ---
#     Digite a palavra inicial da frase 2: Bem
#     Frase gerada: Bem, que queria privá-lo de Narciso, ou volta de sol daquele amigo.
#     ---
#     Digite a palavra inicial da frase 3: Parece
#     Frase gerada: Parece que é essa lembrança.
#     ---
#     Digite a palavra inicial da frase 4: Major
#     Frase gerada: Major Siqueira, leitor.
#
#     FIM
# O Almada
#
#     ESCREVENDO "como" MACHADO DE ASSIS!
#
#     Digite o nome do arquivo com o texto: almada.txt
#     Digite o numero de frases que devem ser geradas: 3
#     ---
#     Digite a palavra inicial da frase 1: Este
#     Frase gerada: Este, porque o pensamento Velava inteiro, Tal rugindo de vaidade, sempre igual destino Nos volumes, co’os mimosos dedos Entretecia, A vida do prelado jaz ninguém descobre, inda estendido, Busca evitar do Almada.
#     ---
#     Digite a palavra inicial da frase 2: casa
#     Frase gerada: casa De baixa a toda se ao grande e fugindo Ao cozinheiro vai do colégio Alvo há pouco As lançou na cabeça o Cardoso forte Almada, que ilustre Da vida, Isto dizendo Numa jaula fechada não fala: “ Guerra ao régio voto teu afeto.
#     ---
#     Digite a palavra inicial da frase 3: tais
#     Frase gerada: tais escuta Almada E de gosto interpretar que o lustre, amada minha cólera Nenhuma frase; ora, Trovejando vermelho se passa, segundo as finezas As sandálias à causa sua arenga Quando nele contempla os reverendos “ Não lográssemos nós todos, boca Aos macios colchões lhe agradece Ao céu; sacode Que seria da igreja .VIII Os negros fios ásperos sacode o Dom Abade, Da inércia do homem, As ruas.
#
#     FIM
#
# Dom Casmurro
#
#     ESCREVENDO "como" MACHADO DE ASSIS!
#
#     Digite o nome do arquivo com o texto: dom_casmurro.txt
#     Digite o numero de frases que devem ser geradas: 5
#     ---
#     Digite a palavra inicial da frase 1: amigas
#     Frase gerada: amigas que era obra modesta, sorria; e tiraram o meu pai foi enorme.
#     ---
#     Digite a palavra inicial da frase 2: Segredo
#     Frase gerada: Segredo por mais que contarei no chão.
#     ---
#     Digite a palavra inicial da frase 3: Os
#     Frase gerada: Os vizinhos tinha e pedi ao ver sem as letras dispensáveis, falando do dó fez-se pajem, um com Deus Nosso Senhor lhe enchesse a qualquer outro daqui não marcado, sejam sujeitas a patena.
#     ---
#     Digite a palavra inicial da frase 4: outro
#     Frase gerada: outro, Santiago, o que outra coisa de Sirach, ou o leitor precoce.
#     ---
#     Digite a palavra inicial da frase 5: Capitu
#     Frase gerada: Capitu, além dos passarinhos do qual não chegue para cima da natureza.
#
#     FIM
#
#
# Memórias Póstumas de Brás Cubas
#     ESCREVENDO "como" MACHADO DE ASSIS!
#
#     Digite o nome do arquivo com o texto: memorias_postumas.txt
#     Digite o numero de frases que devem ser geradas: 5
#     ---
#     Digite a palavra inicial da frase 1: Dito
#     Frase gerada: Dito e, e experimentada, e vinha montado; gemia o matou.
#     ---
#     Digite a palavra inicial da frase 2: Com
#     Frase gerada: Com efeito, podia atraí-la à maravilha.
#     ---
#     Digite a palavra inicial da frase 3: Mas
#     Frase gerada: Mas a infeliz V / A briga.
#     ---
#     Digite a palavra inicial da frase 4: duras
#     Frase gerada: duras, e não quis vestir-me, mas não sei, a mão dos juros.
#     ---
#     Digite a palavra inicial da frase 5: duras
#     Frase gerada: duras, punha-lhe um eco delicioso, os navios são obrigados a palmeira, ouvindo e deslembrado, senhor deve zelar o Coronel Paulo.
#
#     FIM
#
# Tudo
#     ESCREVENDO "como" MACHADO DE ASSIS!
#
#     Digite o nome do arquivo com o texto: tudo.txt
#     Digite o numero de frases que devem ser geradas: 10
#     ---
#     Digite a palavra inicial da frase 1: Hoje
#     Frase gerada: Hoje convidou o que te ordenares padre, depois replicou-me sem esquecer, Lhes doerá nas salas e se admire do rosto é apressá-la.
#     ---
#     Digite a palavra inicial da frase 2: Capitu
#     Frase gerada: Capitu, mas não era a deitar-se, sem estas mãos e mobília velha, tal ponto do Quincas Borba divergiu do outro termo aos poucos anos Encerrá-lo em volta de uma curiosa.
#     ---
#     Digite a palavra inicial da frase 3: Borba
#     Frase gerada: Borba.
#     ---
#     Digite a palavra inicial da frase 4: sacrifício
#     Frase gerada: sacrifício com as carícias para mirá-los mais que a decifração da morte não falta.
#     ---
#     Digite a palavra inicial da frase 5: falta
#     Frase gerada: falta do Mustre A promessa, as últimas palavras, e foi só um ritual excitava-o mais belas obras alheias, Co’os homens; e grulha, que podia antepô-lo a vida.
#     ---
#     Digite a palavra inicial da frase 6: vida
#     Frase gerada: vida, contraindo as borlas caídas do moço que era ela estendendo as grandes comodidades.
#     ---
#     Digite a palavra inicial da frase 7: comodidades
#     Frase gerada: comodidades.
#     ---
#     Digite a palavra inicial da frase 8: Bentinho
#     Frase gerada: Bentinho!
#     ---
#     Digite a palavra inicial da frase 9: Bentinho
#     Frase gerada: Bentinho há pouco espantada, dando-lhe ela me o grito de camarista, porque ele; mas trocados no susto Alguns minutos de nove anos iam adiante, de tudo, parece que dará um embrulho e vinhetas.
#     ---
#     Digite a palavra inicial da frase 10: grito
#     Frase gerada: grito, pequeno legado, ou pequenas.
# FIM

# %%
#------------------------------------------------------------------
# MODULOS A SEREM UTILIZADOS NO PROGRAMA
import random # para random.choice(lista) na função gere_frase()

#------------------------------------------------------------------
# CONSTANTES

# ponto final, ponto de interrogação, ponto de exclamação
# não consideraremos reticências "..."
PONTUACAO_FINAL = ".?!"

# vírgula, ponto e vírgula, dois pontos, fecha parênteses
# não devem ser precedidos de espaço na frase gerada
PONTUACAO_SEM_ESPACO = ',;:)' + PONTUACAO_FINAL

# travesão, aspas, abre chaves
# devem ser precedidos de espaço na frase gerada
PONTUACAO_COM_ESPACO = '—"('

# todas juntas (reticências foram desconsideradas)
PONTUACAO = PONTUACAO_SEM_ESPACO + PONTUACAO_COM_ESPACO

# usado na função insira espacos
ESPACO = ' '

# semente para o gerador aleatório com o objetivo de reprodutibilidade
SEED = 1234

#------------------------------------------------------------------
#
def main():
    '''(None) -> None

    Para testar as funções juntas. Esta função não será avaliada, entretanto
    ela __não__ deve gerar erro de execução ou sintático. 
    Modifique-a se desejar.
    '''
    # Para efeitos de reprodutibilidade
    random.seed(SEED)

    print('ESCREVENDO "como" MACHADO DE ASSIS!\n')

    # 1 leia nome do arquivo 
    nome = input("Digite o nome do arquivo com o texto: ")

    # 2 leia o corpus
    try:
        with open(nome, "r", encoding="utf-8") as arq:
            texto = arq.read()
    except:
        print(f"main(): Erro na leitura do arquivo '{nome}'")
        return None
    
    # 3 insira espaços antes de pontuações
    texto = insira_espacos(texto)

    # 4 obtenha lista com itens léxicos
    lst_itens = texto.split()
    
    # 5 construa dicionario de sucessores
    dicio = dicio_sucessores(lst_itens)

    # 6 quantidade de frases que devem ser geradas
    n = int(input("Digite o numero de frases que devem ser geradas: "))

    # 7 gere as frase
    for i in range(n):
        # gere i-ésima frase
        print("---")

        # 7.1 pegue palavra inicial da frase a ser gerada
        palavra_inicial = input(f"Digite a palavra inicial da frase {i+1}: ")

        # 7.2 gere uma frase começando com palavra_inicial 
        frase = gere_frase(palavra_inicial, dicio)
        print("Frase gerada:", frase)

    print("\nFIM")

#------------------------------------------------------------------
def insira_espacos(txt):
    '''(str) -> str

    RECEBE uma string `txt`.
    RETORNA a string resultante da inserção de um ESPACO antes e depois de 
    __cada sinal__ em PONTUACAO que estiver em texto.
    '''
    # modifique o código abaixo para conter a sua solução.
    
    frase_com_espacos = ""
    
    for palavra in txt:
        
        if palavra in PONTUACAO:
            frase_com_espacos += ESPACO + palavra + ESPACO
        else:
            frase_com_espacos += palavra
    return frase_com_espacos



#------------------------------------------------------------------
def dicio_sucessores(lst):
    '''(list) -> dict

    RECEBE uma lista `lst`.
    RETORNA um dicionário em que 

        - as __chaves__ são os itens que ocorrem em lst e 
        - o  __valor__ associado a cada chave é a lista dos 
          itens que ocorrem imediatamente após a chave na lista lst.

    Por convenção a lista correspondente ao valor do último item 
    na lst (=lst[-1]) contém o primeiro item da lista (=lst[0]).

    Se a `lst` é a lista vazia a função deve retornar o dicionário vazio.
    '''
    # modifique o código abaixo para conter a sua solução.
    
    dicionario = {}
    
    for palavra in lst:
        if palavra not in dicionario:
            for termo in range(len(lst)):
                if palavra == lst[termo]:
                    if palavra not in dicionario:
                        dicionario[palavra] = []
                    try:
                        dicionario[palavra].append(lst[termo + 1])
                    except:
                        dicionario[palavra].append(lst[0])
    print(dicionario)
    return dicionario

#------------------------------------------------------------------
def gere_frase(p_inicial, dicio):
    '''(str, dict) -> str

    RECEBE uma palavra `p_inicial` e um dicionário `dicio`.

    O dicionário foi criado a partir de um texto com uma ou 
    mais frase; como nos textos de Machado de Assis.

    Cada chave do dicionário é um item (str). O valor no dicionário 
    correspondente a uma chave é uma lista (list) de itens (str). 

    RETORNA uma string representando uma frase.

    A frase retornada deve começar com a string p_inicial e ser gerada 
    segundo o __processo aleatório__ descrito no enunciado.
    
    Os itens na frase devem ser precedidos de um ESPACO, exceto:

        - a palavra inicial e
        - e os sinais de pontuação na string PONTUACAO_SEM_ESPACO.

    Se p_inicial não está no dicionário a função deve retornar a string vazia.
    '''
    # modifique o código abaixo para conter a sua solução.
    
    if p_inicial in dicio:
        frase_gerada = p_inicial
        escolha_aleatoria = random.choice(dicio[p_inicial])
        is_pont_fin = False
        while not is_pont_fin:
            if escolha_aleatoria in PONTUACAO_FINAL:
                frase_gerada += escolha_aleatoria
                is_pont_fin = True
            elif escolha_aleatoria in PONTUACAO_SEM_ESPACO:
                frase_gerada += escolha_aleatoria
            elif escolha_aleatoria in PONTUACAO_COM_ESPACO:
                frase_gerada += ESPACO + escolha_aleatoria
            else:
                frase_gerada += ESPACO + escolha_aleatoria
            escolha_aleatoria = random.choice(dicio[escolha_aleatoria])
        return frase_gerada

    else:
        return ""
                            

#######################################################
###                 FIM                             ###
#######################################################
#
# Não modifique as linhas abaixo
#
# Esse if serve para rodar a main() dentro do Spyder
# e não atrapalhar o corretor automático
# COMENTE as linhas a seguir durante os testes das suas
# funções no Python Shell

if __name__ == '__main__':
    main()
